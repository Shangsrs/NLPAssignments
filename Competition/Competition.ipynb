# %%
data_file = "D:\\python\\datasource\\Competition\\pv_uv_data.rar"

# %% [raw]
# from unrar import rarfile
#
# rar_file = rarfile.RarFile(data_file, mode='r')
# rar_file.extractall()
#
# rar_file.namelist()

# %%
import pandas as pd

# %%
import os

# %%
data_root = "D:\\python\\datasource\\Competition\\PV_UV_data"

# %%
path = os.path.join(data_root, "event_detail.csv")
event_detail = pd.read_csv(path)
# Out:
# C:\Users\wang.kui\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (16,17,18,28,32,34,38,41,42,45,49,50,59,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
for i in event_detail:
    print(i, end=" ")
    print(event_detail[i][0])
print(len(event_detail))
# event_detail.fillna(' ')
# event_detail.head()
# Out:
# distinct_id -5244847218789979212
# time 20181123
# xwhat $startup
# $browser nan
# $browser_version nan
# $is_first_day 1.0
# $is_login 0
# $lib JS
# $lib_version 4.1.2
# $os nan
# $os_version nan
# $platform JS
# $screen_height 1024.0
# $screen_width 1024.0
# $title nan
# $url nan
# $country 中国
# $province 北京
# $city 北京
# $referrer nan
# $is_first_time 1.0
# $model nan
# $brand nan
# $utm_campaign nan
# $utm_content nan
# $utm_medium nan
# $utm_source nan
# $utm_term nan
# $utm_campaign_id nan
# $startup_time nan
# $time_zone GMT-08:00
# $web_crawler 1.0
# $traffic_source_type nan
# $search_engine nan
# $social_share_from nan
# $referrer_domain nan
# $social nan
# $scene nan
# $search_keyword nan
# $scene_type nan
# $channel nan
# $language nan
# $session_id nan
# $social_media nan
# $signup_time nan
# $url_domain nan
# $is_time_calibrated nan
# $click_x nan
# $click_y nan
# $device_type nan
# $element_path nan
# $page_height nan
# $page_width nan
# $event_duration nan
# ...

# %%
index = []
for i in event_detail['$title']:
    i = str(i)
    i = i.strip()
    if i == 'nan': continue
    index.append(i)
len(index)
# Out:
# 1973970

# %%
path = os.path.join(data_root, "kpi_train.csv")
kpi_train = pd.read_csv(path)

# %%
for i in kpi_train:
    print(i, end=" ")
    print(kpi_train[i][0])
print(len(kpi_train))
# kpi_train.fillna(' ')
# Out:
# date 20181101
# event_type $pageview
# pv 6549
# uv 674
# 400
#          date         event_type     pv    uv
# 0    20181101          $pageview   6549   674
# 1    20181101  reg_input_success     29    20
# 2    20181102          $pageview   3972   581
# 3    20181102  reg_input_success     34    21
# 4    20181103          $pageview   1446   395
# 5    20181103  reg_input_success      8     8
# 6    20181104          $pageview   1387   411
# 7    20181104  reg_input_success      7     7
# 8    20181105          $pageview   3656   800
# 9    20181105  reg_input_success     14    14
# 10   20181106          $pageview   4257  1012
# 11   20181106  reg_input_success     33    33
# 12   20181107          $pageview   3813   856
# 13   20181107  reg_input_success     25    25
# 14   20181108          $pageview   4176   875
# 15   20181108  reg_input_success     29    29
# 16   20181109          $pageview   3518   650
# 17   20181109  reg_input_success     24    24
# ...

# %%
path = os.path.join(data_root, "user.csv")
user = pd.read_csv(path)
# Out:
# C:\Users\wang.kui\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
for i in user:
    print(i, end=" ")
    print(user[i][0])
print(len(user))
# user.fillna(' ')
# user.head()
# Out:
# distinct_id -1.0003471929704527e+18
# xwho JS820bf0a2f12620e6cda09629ebc3d738820b
# xwhen 1556786562872.0
# $lib JS
# $lib_version 4.3.0.12
# $original_id nan
# $platform JS
# $first_visit_time 1556786562872.0
# $signup_time nan
# datafrom nan
# data_source nan
# $first_visit_language zh-cn
# $browser_version nan
# $os_version nan
# $web_crawler nan
# $is_first_day nan
# $os nan
# $screen_width nan
# $startup_time nan
# $screen_height nan
# $browser nan
# $referrer nan
# $language nan
# $title nan
# $referrer_domain nan
# $url nan
# $time_zone nan
# $session_id nan
# $model nan
# $brand nan
# $user_agent nan
# 569695

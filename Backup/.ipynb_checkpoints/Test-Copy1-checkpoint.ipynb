# %%
WikiCorpus?

# %% [markdown]
# ## 词向量训练

# %%
import gensim
from gensim.corpora import WikiCorpus
import jieba
from langconv import *
import re

# %% [raw]
# def wiki_process():
#     space = ' '
#     i = 0
#     l = []
#     #zhwiki_name = 'D:\python\datasource\wiki_data\zhwiki-pages-articles-multistream.xml.bz2'
#     zhwiki_name = 'D:\python\datasource\wiki_data\process\AA\wiki_00.bz2'
#     f = open('D:\python\datasource\wiki_data/reduce_zhiwiki.txt','w',encoding = 'utf-8')
#     print('WikiCorpus 1')
#     wiki = WikiCorpus(zhwiki_name, lemmatize=False, dictionary={})
#     print('WikiCorpus 2')
#     for text in wiki.get_texts():
#         for temp_sentence in text:
#             temp_sentence = Converter('zh-hans').convert(temp_sentence)
#             seg_list = list(jieba.cut(temp_sentence))
#             for temp_term in seg_list:
#                 l.append(temp_term)
#             #print(l)
#         f.write(space.join(l) + '\n')
#         l = []
#         i = i + 1
#         if (i%2000 == 0):#设置读取文章数量
#             print('Saved ' + str(i) + 'articles')
#             f.close()
#             return
#     f.close()

# %%
def wiki_process():
    space = ' '
    i = 0
    l = []
    #zhwiki_name = 'D:\python\datasource\wiki_data\zhwiki-pages-articles-multistream.xml.bz2'
    zhwiki_name = 'D:\python\datasource\wiki_data\process\AA\wiki_00'
    f = open('D:\python\datasource\wiki_data/reduce_zhiwiki.txt','w',encoding = 'utf-8')
    wikiFile = open(zhwiki_name,'r',encoding='utf-8')
    for text in wikiFile:
        text = text.strip()
        if !text: continue
        if re.match(r'<.*>',text): continue
        text = re.findall(r'\w+',text)
        temp_sentence = Converter('zh-hans').convert(text)
        seg_list = list(jieba.cut(temp_sentence))
        for temp_term in seg_list:
            l.append(temp_term)
        #print(l)
        f.write(space.join(l) + '\n')
        l = []
        i = i + 1
        if (i%2000 == 0):#设置读取文章数量
            print('Saved ' + str(i) + 'articles')
#             f.close()
#             return
    f.close()

# %%
wiki_process()
# Out:
# Saved 2000articles
# Saved 4000articles
# Saved 6000articles
# Saved 8000articles
# Saved 10000articles
# Saved 12000articles
# Saved 14000articles
# Saved 16000articles
# Saved 18000articles
# Saved 20000articles
# Saved 22000articles
# Saved 24000articles
# Saved 26000articles
# Saved 28000articles
# Saved 30000articles
# Saved 32000articles
# Saved 34000articles
# Saved 36000articles
# Saved 38000articles
# Saved 40000articles
# Saved 42000articles
# Saved 44000articles
# Saved 46000articles
# Saved 48000articles
# Saved 50000articles
# Saved 52000articles
# Saved 54000articles
# Saved 56000articles
# Saved 58000articles
# Saved 60000articles
# Saved 62000articles
# Saved 64000articles
# Saved 66000articles
# Saved 68000articles
# Saved 70000articles
# Saved 72000articles
# Saved 74000articles
# Saved 76000articles
# Saved 78000articles
# Saved 80000articles
# Saved 82000articles
# Saved 84000articles
# Saved 86000articles
# Saved 88000articles
# Saved 90000articles
# Saved 92000articles
# Saved 94000articles
# Saved 96000articles
# Saved 98000articles
# Saved 100000articles
# Saved 102000articles
# Saved 104000articles
# Saved 106000articles
# Saved 108000articles

# %%
from gensim.models import Word2Vec
from gensim.models.word2vec import LineSentence
import logging

# %% [raw]
# logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
def train():
    wiki_news = open('D:\python\datasource\wiki_data/reduce_zhiwiki.txt', 'r',encoding='utf-8')
    model = Word2Vec(LineSentence(wiki_news),sg=0, size=192, window=5,min_count=5, workers=5)
    model.save('D:\python\datasource\wiki_data\zhiwiki_news.word2vec')

# %%
train()

# %%
model = Word2Vec.load('D:\python\datasource\wiki_data\zhiwiki_news.word2vec')

# %%
print(model.wv.similarity('天气','预报'))
# Out:
# 0.6719331

# %%
print(model.wv.similarity('优秀','富裕'))
# Out:
# 0.6080275

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# %%
def tsne_plot(model):
    labels = []
    tokens = []
    i = 0
    for word in model.wv.vocab:
        tokens.append(model[word])
        labels.append(word)
        i += 1
        if i > 1000: break
    print(len(labels),len(tokens))
    tsne_model = TSNE(perplexity=40, n_components=2, init='pca', n_iter=2500, random_state=23)
    new_values = tsne_model.fit_transform(tokens)
    
    x = []
    y = []
    for value in new_values:
        x.append(value[0])
        y.append(value[1])
    plt.figure(figsize = (16,16))
    print(len(x))
    for i in range(len(x)):
        plt.scatter(x[i],y[i])
        plt.annotate(labels[i],xy=(x[i],y[i]), xytext=(5,2), 
                     textcoords='offset points', ha='right', va='bottom')
    plt.show()

# %%
tsne_plot(model)
# Out:
# C:\Users\wang.kui\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# 1001 1001
# 1001

# %%
model?

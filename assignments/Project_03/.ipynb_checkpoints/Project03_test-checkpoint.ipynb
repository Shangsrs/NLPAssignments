# %%
import numpy as np
import pandas as pd

# %%
train_file = '/python/datasource/project/comment-classification/ai_challenger_sentiment_analysis_testa_20180816/sentiment_analysis_testa.csv'
test_file = '/python/datasource/project/comment-classification/ai_challenger_sentiment_analysis_trainingset_20180816/sentiment_analysis_trainingset.csv'
valid_file = '/python/datasource/project/comment-classification/ai_challenger_sentiment_analysis_validationset_20180816/sentiment_analysis_validationset.csv'

# %%
train_data = pd.read_csv(train_file)
train_data.head()
# Out:
#    id                                            content  \
# 0   0  "我想说他们家的优惠活动好持久啊，我预售的时候买的券，前两天心血来潮去吃的活动还在继续\n首...
# 1   1  "终于开到心心念念的LAB loft。第一次来就随便点也一些～【香辣虾意面】蛮辣的，但其实一...
# 2   2  "地理位置好，交通方便，就在124车站对面交通方便，很好，我晚上7点多去买的了，已经没有什么...
# 3   3  "运气很好，抽中了大众点评的霸王餐。这家主题餐厅心仪已久了，种种原因一直未能成行，没想到抽中...
# 4   4  "幸运随点评团体验霸王餐，心情好~蜀九香刚进驻泉州不久，招牌大名气响，以至于刚到店门口的我被...
#
#    location_traffic_convenience  location_distance_from_business_district  \
# 0                           NaN                                       NaN
# 1                           NaN                                       NaN
# 2                           NaN                                       NaN
# 3                           NaN                                       NaN
# 4                           NaN                                       NaN
#
#    location_easy_to_find  service_wait_time  service_waiters_attitude  \
# 0                    NaN                NaN                       NaN
# ...

# %%
test_data = pd.read_csv(test_file)
test_data.head()
# Out:
#    id                                            content  \
# 0   0  "吼吼吼，萌死人的棒棒糖，中了大众点评的霸王餐，太可爱了。一直就好奇这个棒棒糖是怎么个东西，...
# 1   1  "第三次参加大众点评网霸王餐的活动。这家店给人整体感觉一般。首先环境只能算中等，其次霸王餐提...
# 2   2  "4人同行 点了10个小吃\n榴莲酥 榴莲味道不足 松软 奶味浓\n虾饺 好吃 两颗大虾仁\...
# 3   3  "之前评价了莫名其妙被删 果断继续差评！ 换了菜单 价格更低 开始砸牌子 但套餐还是有150...
# 4   4  "出乎意料地惊艳，椰子鸡清热降火，美容养颜，大大满足了爱吃火锅怕上火星人。椰子冻是帅帅的老板...
#
#    location_traffic_convenience  location_distance_from_business_district  \
# 0                            -2                                        -2
# 1                            -2                                        -2
# 2                            -2                                        -2
# 3                            -2                                        -2
# 4                            -2                                        -2
#
#    location_easy_to_find  service_wait_time  service_waiters_attitude  \
# 0                     -2                 -2                         1
# ...

# %%
valid_data = pd.read_csv(valid_file)
valid_data.head()
# Out:
#    id                                            content  \
# 0   0  "哎，想当年来佘山的时候，啥都没有，三品香算镇上最大看起来最像样的饭店了。菜品多，有点太多，...
# 1   1  "趁着国庆节，一家人在白天在山里玩耍之后，晚上决定吃李记搅团。\n东门外这家店门口停车太难了...
# 2   2  "这家店是我目前吃到的最干净的串串店，目前看到最有意思的串串店。\n菜单是张试题卷，很有新意...
# 3   3  "中午和领导偷偷跑出来开小灶啦，到这家来顿料理，解馋之余放松放松，日本的习惯是这样吗，哈哈哈...
# 4   4  "    拖了很久很久才来补的点评，之前和朋友一块儿去的，用的是代金卷（不晓得现在这家店还在...
#
#    location_traffic_convenience  location_distance_from_business_district  \
# 0                            -2                                        -2
# 1                            -2                                        -2
# 2                            -2                                        -2
# 3                            -2                                        -2
# 4                            -2                                        -2
#
#    location_easy_to_find  service_wait_time  service_waiters_attitude  \
# 0                     -2                  0                        -2
# ...

# %%
train_data.info(), len(train_data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 22 columns):
# id                                          15000 non-null int64
# content                                     15000 non-null object
# location_traffic_convenience                0 non-null float64
# location_distance_from_business_district    0 non-null float64
# location_easy_to_find                       0 non-null float64
# service_wait_time                           0 non-null float64
# service_waiters_attitude                    0 non-null float64
# service_parking_convenience                 0 non-null float64
# service_serving_speed                       0 non-null float64
# price_level                                 0 non-null float64
# price_cost_effective                        0 non-null float64
# price_discount                              0 non-null float64
# environment_decoration                      0 non-null float64
# ...
